# %%
# Cell 1 — Install packages and download/extract TGIF subset
# !pip install -q segmentation-models-pytorch albumentations timm opencv-python-headless kaggle

import os
import zipfile
import subprocess
from pathlib import Path

# IMPORTANT:
# Replace YOUR_KEY with your real Kaggle API key before running.
os.makedirs('/root/.kaggle', exist_ok=True)
with open('/root/.kaggle/kaggle.json', 'w') as f:
    f.write('{"username":"ahnafnafim","key":"YOUR_KEY"}')
os.chmod('/root/.kaggle/kaggle.json', 0o600)

ZIP_PATH = Path('/kaggle/working/tgif-subset.zip')
EXTRACT_ROOT = Path('/kaggle/working')
DATA_ROOT_PATH = EXTRACT_ROOT / 'subset'

if DATA_ROOT_PATH.exists():
    print(f"✓ Dataset already extracted at: {DATA_ROOT_PATH}")
else:
    print("Downloading TGIF subset from Kaggle...")
    subprocess.run(
        [
            'kaggle', 'datasets', 'download',
            '-d', 'araftahsanpavel/tgif-subset',
            '-p', str(EXTRACT_ROOT)
        ],
        check=True
    )

    print("Extracting...")
    with zipfile.ZipFile(ZIP_PATH, 'r') as z:
        z.extractall(EXTRACT_ROOT)

    if ZIP_PATH.exists():
        ZIP_PATH.unlink()

    print(f"✓ Extracted to: {DATA_ROOT_PATH}")

# Quick structure check
for split in ['training', 'validation', 'testing']:
    split_dir = DATA_ROOT_PATH / split
    print(f"\n{split_dir}")
    for sub in ['fakes', 'images', 'masks']:
        sub_dir = split_dir / sub
        n_files = sum(1 for p in sub_dir.rglob('*') if p.is_file()) if sub_dir.exists() else 0
        print(f"  {sub:<8} exists={sub_dir.exists()} files={n_files}")

print("\n✓ Done")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 8.4 MB/s eta 0:00:00
# ✓ Dataset already extracted at: /kaggle/working/subset
#
# /kaggle/working/subset/training
#   fakes    exists=True files=5459
#   images   exists=True files=2100
#   masks    exists=True files=4200
#
# /kaggle/working/subset/validation
#   fakes    exists=True files=682
#   images   exists=True files=341
#   masks    exists=True files=682
#
# /kaggle/working/subset/testing
#   fakes    exists=True files=686
#   images   exists=True files=343
#   masks    exists=True files=686
#
# ✓ Done

# %%
# Cell 2 — Imports, hyperparameters, and reproducibility setup
import os, time, random, json, gc
from pathlib import Path

import cv2
import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.amp import GradScaler, autocast

import albumentations as A
from albumentations.pytorch import ToTensorV2

import segmentation_models_pytorch as smp
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# =========================
# Hyperparameters
# =========================
SEED = 42
IMG_SIZE = 384

# Use 4 for EfficientNetV2-L and Swin-B 384 on Kaggle.
# If EfficientNet-B4 fits easily, you may try 8 for that specific experiment.
BATCH_SIZE = 8

NUM_EPOCHS = 20
LR = 1e-4
WEIGHT_DECAY = 1e-4
GRAD_CLIP = 1.0

# Optional. Keep None for "no pos_weight".
# Use POS_WEIGHT in run_experiment(..., pos_weight=POS_WEIGHT) if recall is too low.
POS_WEIGHT = 3.0

NUM_WORKERS = 2        # safer on Kaggle; use 4 only if your session is stable
PATIENCE = 5
BINARY_THRESHOLD = 0.5

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
USE_AMP = (DEVICE.type == 'cuda')
PIN_MEMORY = (DEVICE.type == 'cuda')

DATA_ROOT = '/kaggle/working/subset'
SAVE_DIR = '/kaggle/working'

MEAN = [0.485, 0.456, 0.406]
STD  = [0.229, 0.224, 0.225]
IMG_EXTS = {'.jpg', '.jpeg', '.png', '.bmp', '.tif', '.tiff', '.webp'}

# Speed/reproducibility balance:
# deterministic=True gives more reproducible runs, but benchmark=True is faster for fixed 384 input.
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)

if DEVICE.type == 'cuda':
    torch.cuda.manual_seed_all(SEED)
    torch.backends.cudnn.deterministic = False
    torch.backends.cudnn.benchmark = True

print(f"Device: {DEVICE}")
if DEVICE.type == 'cuda':
    print(f"GPU: {torch.cuda.get_device_name(0)}")
print(f"DATA_ROOT exists: {os.path.exists(DATA_ROOT)}")
# Out:
# Device: cuda
# GPU: Tesla T4
# DATA_ROOT exists: True

# %%
# Cell 3 — Dataset class, transforms, and DataLoaders

def is_image_file(path):
    return Path(path).suffix.lower() in IMG_EXTS


def normalized_stem(path):
    stem = Path(path).stem.lower()
    for token in [
        '_mask', '-mask', '_masks', '-masks',
        '_gt', '-gt', '_label', '-label',
        '_labels', '-labels', '_forged', '-forged',
        '_fake', '-fake'
    ]:
        stem = stem.replace(token, '')
    return stem


class TGIFSubsetDataset(Dataset):
    """
    Expected structure:
    /kaggle/working/subset/
        training/
            fakes/
            images/
            masks/
        validation/
            fakes/
            images/
            masks/
        testing/
            fakes/
            images/
            masks/

    Forged sample:
        input = fakes image
        target = corresponding mask
        image-level label = 1

    Authentic sample:
        input = images image
        target = all-zero mask
        image-level label = 0
    """
    def __init__(self, root, split='training', transform=None, include_authentic=True, verbose=True):
        self.root = root
        self.split = split
        self.transform = transform
        self.include_authentic = include_authentic
        self.samples = []

        split_dir = Path(root) / split
        fakes_dir = split_dir / 'fakes'
        masks_dir = split_dir / 'masks'
        images_dir = split_dir / 'images'

        if not fakes_dir.exists():
            raise FileNotFoundError(f"Missing fakes directory: {fakes_dir}")
        if not masks_dir.exists():
            raise FileNotFoundError(f"Missing masks directory: {masks_dir}")

        fake_files = sorted([p for p in fakes_dir.rglob('*') if p.is_file() and is_image_file(p)])
        mask_files = sorted([p for p in masks_dir.rglob('*') if p.is_file() and is_image_file(p)])

        # Keep masks grouped by category/subfolder so names do not collide across generators/categories.
        masks_by_parent = {}
        for m in mask_files:
            rel_parent = str(m.parent.relative_to(masks_dir)).lower()
            masks_by_parent.setdefault(rel_parent, []).append(m)

        unmatched = []

        for fake_path in fake_files:
            rel_parent = str(fake_path.parent.relative_to(fakes_dir)).lower()
            candidate_masks = masks_by_parent.get(rel_parent, [])

            fake_name_lower = fake_path.name.lower()
            fake_stem = normalized_stem(fake_path)

            matched_mask = None

            # First try exact-ish stem matching.
            for mask_path in candidate_masks:
                mask_name_lower = mask_path.name.lower()
                mask_stem = normalized_stem(mask_path)

                if (
                    fake_stem == mask_stem
                    or fake_stem.startswith(mask_stem)
                    or mask_stem in fake_stem
                    or fake_name_lower.startswith(mask_name_lower)  # supports names like "abc.png_fake.png"
                ):
                    matched_mask = mask_path
                    break

            if matched_mask is not None:
                self.samples.append((str(fake_path), str(matched_mask), 1))
            else:
                unmatched.append(str(fake_path))

        if include_authentic and images_dir.exists():
            authentic_files = sorted([p for p in images_dir.rglob('*') if p.is_file() and is_image_file(p)])
            for img_path in authentic_files:
                self.samples.append((str(img_path), None, 0))

        n_forged = sum(1 for s in self.samples if s[2] == 1)
        n_auth = sum(1 for s in self.samples if s[2] == 0)

        if verbose:
            print(f"  {split}: {len(self.samples)} total ({n_forged} forged, {n_auth} authentic)")
            print(f"    fake files found: {len(fake_files)} | masks found: {len(mask_files)} | unmatched fakes: {len(unmatched)}")
            if unmatched[:3]:
                print("    sample unmatched:")
                for u in unmatched[:3]:
                    print("     ", u)

        if len(self.samples) == 0:
            raise RuntimeError(f"No samples found for split={split}. Check DATA_ROOT and folder structure.")

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        img_path, mask_path, label = self.samples[idx]

        image = np.array(Image.open(img_path).convert('RGB'))

        if mask_path is not None:
            mask_img = Image.open(mask_path).convert('L')
            if mask_img.size != (image.shape[1], image.shape[0]):
                mask_img = mask_img.resize((image.shape[1], image.shape[0]), resample=Image.NEAREST)

            mask = np.array(mask_img)
            mask = (mask > 127).astype(np.float32)
        else:
            mask = np.zeros((image.shape[0], image.shape[1]), dtype=np.float32)

        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask  = augmented['mask']

        if isinstance(mask, np.ndarray):
            mask = torch.from_numpy(mask)

        mask  = mask.unsqueeze(0).float()
        label = torch.tensor(float(label))

        return image, mask, label


def get_transforms(augment=False):
    if not augment:
        return A.Compose([
            A.Resize(IMG_SIZE, IMG_SIZE, interpolation=cv2.INTER_LINEAR),
            A.Normalize(mean=MEAN, std=STD),
            ToTensorV2(),
        ])

    return A.Compose([
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.3),
        A.RandomRotate90(p=0.3),
        A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.1, hue=0.0, p=0.4),

        # Keep resize after geometric transforms so every batch is fixed-size.
        A.Resize(IMG_SIZE, IMG_SIZE, interpolation=cv2.INTER_LINEAR),

        A.Normalize(mean=MEAN, std=STD),
        ToTensorV2(),
    ])


def make_loaders(augment=False, batch_size=BATCH_SIZE, include_authentic=True):
    train_tf = get_transforms(augment=augment)
    val_tf = get_transforms(augment=False)

    print(f"Building datasets | augmentation={augment} | batch_size={batch_size}")

    train_ds = TGIFSubsetDataset(DATA_ROOT, 'training', transform=train_tf, include_authentic=include_authentic)
    val_ds   = TGIFSubsetDataset(DATA_ROOT, 'validation', transform=val_tf, include_authentic=include_authentic)
    test_ds  = TGIFSubsetDataset(DATA_ROOT, 'testing', transform=val_tf, include_authentic=include_authentic)

    train_loader = DataLoader(
        train_ds,
        batch_size=batch_size,
        shuffle=True,
        num_workers=NUM_WORKERS,
        pin_memory=PIN_MEMORY,
        drop_last=True
    )

    val_loader = DataLoader(
        val_ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=PIN_MEMORY
    )

    test_loader = DataLoader(
        test_ds,
        batch_size=batch_size,
        shuffle=False,
        num_workers=NUM_WORKERS,
        pin_memory=PIN_MEMORY
    )

    return train_loader, val_loader, test_loader


# Smoke test with no augmentation
train_loader, val_loader, test_loader = make_loaders(augment=False, batch_size=BATCH_SIZE)

batch = next(iter(train_loader))
print(f"\nBatch — Image: {batch[0].shape}, Mask: {batch[1].shape}, Label: {batch[2].shape}")
# Out:
# Building datasets | augmentation=False | batch_size=8
#   training: 7559 total (5459 forged, 2100 authentic)
#     fake files found: 5459 | masks found: 4200 | unmatched fakes: 0
#   validation: 1023 total (682 forged, 341 authentic)
#     fake files found: 682 | masks found: 682 | unmatched fakes: 0
#   testing: 1029 total (686 forged, 343 authentic)
#     fake files found: 686 | masks found: 686 | unmatched fakes: 0
#
# Batch — Image: torch.Size([8, 3, 384, 384]), Mask: torch.Size([8, 1, 384, 384]), Label: torch.Size([8])

# %%
# Cell 4 — Loss, training, validation, evaluation, and plotting utilities

class DiceBCELoss(nn.Module):
    def __init__(self, smooth=1.0, pos_weight=None):
        super().__init__()
        self.smooth = smooth

        if pos_weight is not None:
            self.register_buffer("pos_weight", torch.tensor([pos_weight], dtype=torch.float32))
        else:
            self.pos_weight = None

    def forward(self, logits, targets):
        if self.pos_weight is not None:
            bce_loss = F.binary_cross_entropy_with_logits(
                logits,
                targets,
                pos_weight=self.pos_weight.to(logits.device)
            )
        else:
            bce_loss = F.binary_cross_entropy_with_logits(logits, targets)

        preds = torch.sigmoid(logits).view(logits.size(0), -1)
        tgt = targets.view(targets.size(0), -1)

        intersection = (preds * tgt).sum(dim=1)
        union = preds.sum(dim=1) + tgt.sum(dim=1)

        dice_loss = 1.0 - ((2.0 * intersection + self.smooth) / (union + self.smooth)).mean()

        return 0.5 * bce_loss + 0.5 * dice_loss


def train_one_epoch(model, loader, criterion, optimizer, scaler, device):
    model.train()
    total_loss, correct, total = 0.0, 0, 0
    start = time.time()

    for images, masks, labels in loader:
        images = images.to(device, non_blocking=True)
        masks  = masks.to(device, non_blocking=True)

        optimizer.zero_grad(set_to_none=True)

        with autocast(device_type=device.type, enabled=USE_AMP):
            logits = model(images)
            loss = criterion(logits, masks)

        scaler.scale(loss).backward()
        scaler.unscale_(optimizer)
        nn.utils.clip_grad_norm_(model.parameters(), GRAD_CLIP)
        scaler.step(optimizer)
        scaler.update()

        total_loss += loss.item() * images.size(0)

        preds = (torch.sigmoid(logits) > BINARY_THRESHOLD).float()
        correct += (preds == masks).sum().item()
        total += masks.numel()

    return total_loss / len(loader.dataset), correct / total, time.time() - start


@torch.no_grad()
def validate(model, loader, criterion, device):
    model.eval()
    total_loss, correct, total = 0.0, 0, 0

    for images, masks, labels in loader:
        images = images.to(device, non_blocking=True)
        masks  = masks.to(device, non_blocking=True)

        with autocast(device_type=device.type, enabled=USE_AMP):
            logits = model(images)
            loss = criterion(logits, masks)

        total_loss += loss.item() * images.size(0)

        preds = (torch.sigmoid(logits) > BINARY_THRESHOLD).float()
        correct += (preds == masks).sum().item()
        total += masks.numel()

    return total_loss / len(loader.dataset), correct / total


@torch.no_grad()
def full_evaluation(model, loader, device, threshold=BINARY_THRESHOLD):
    """
    Streaming evaluation to avoid storing all pixels from the full dataset in memory.
    Reports both pixel-level localization metrics and image-level fake/authentic metrics.
    """
    model.eval()

    tp = tn = fp = fn = 0
    image_preds = []
    image_targets = []

    for images, masks, labels in loader:
        images = images.to(device, non_blocking=True)

        with autocast(device_type=device.type, enabled=USE_AMP):
            logits = model(images)

        probs = torch.sigmoid(logits).detach().cpu()
        preds = (probs > threshold).int()
        targets = masks.int()

        tp += int(((preds == 1) & (targets == 1)).sum().item())
        tn += int(((preds == 0) & (targets == 0)).sum().item())
        fp += int(((preds == 1) & (targets == 0)).sum().item())
        fn += int(((preds == 0) & (targets == 1)).sum().item())

        # Image-level prediction: if any pixel is predicted forged, image is fake.
        batch_image_preds = (preds.flatten(1).sum(dim=1) > 0).int().numpy().tolist()
        image_preds.extend(batch_image_preds)
        image_targets.extend(labels.int().numpy().tolist())

    eps = 1e-8

    pixel_accuracy = (tp + tn) / (tp + tn + fp + fn + eps)
    pixel_precision = tp / (tp + fp + eps)
    pixel_recall = tp / (tp + fn + eps)
    pixel_f1 = (2 * pixel_precision * pixel_recall) / (pixel_precision + pixel_recall + eps)
    pixel_iou = tp / (tp + fp + fn + eps)
    pixel_dice = (2 * tp) / (2 * tp + fp + fn + eps)

    image_preds = np.array(image_preds)
    image_targets = np.array(image_targets)

    pixel_cm = np.array([[tn, fp], [fn, tp]])
    image_cm = confusion_matrix(image_targets, image_preds, labels=[0, 1])

    return {
        'pixel': {
            'accuracy': float(pixel_accuracy),
            'precision': float(pixel_precision),
            'recall': float(pixel_recall),
            'f1': float(pixel_f1),
            'iou': float(pixel_iou),
            'dice': float(pixel_dice),
        },
        'image': {
            'accuracy': float(accuracy_score(image_targets, image_preds)),
            'precision': float(precision_score(image_targets, image_preds, zero_division=0)),
            'recall': float(recall_score(image_targets, image_preds, zero_division=0)),
            'f1': float(f1_score(image_targets, image_preds, zero_division=0)),
        },
        'pixel_cm': pixel_cm,
        'image_cm': image_cm,
    }


def plot_history(history, model_name, save_dir=SAVE_DIR):
    epochs = range(1, len(history['train_loss']) + 1)

    # Loss curve
    plt.figure(figsize=(7, 5))
    plt.plot(epochs, history['train_loss'], label='Train Loss')
    plt.plot(epochs, history['val_loss'], label='Val Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title(f'{model_name} — Loss Curve')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'{save_dir}/{model_name}_loss_curve.png', dpi=150, bbox_inches='tight')
    plt.show()

    # Val metrics curve
    plt.figure(figsize=(7, 5))
    plt.plot(epochs, history['val_f1'], label='Val F1/Dice')
    plt.plot(epochs, history['val_iou'], label='Val IoU')
    plt.plot(epochs, history['val_precision'], label='Val Precision')
    plt.plot(epochs, history['val_recall'], label='Val Recall')
    plt.xlabel('Epoch')
    plt.ylabel('Metric')
    plt.title(f'{model_name} — Validation Metrics')
    plt.legend()
    plt.grid(True)
    plt.savefig(f'{save_dir}/{model_name}_metrics_curve.png', dpi=150, bbox_inches='tight')
    plt.show()


def plot_confusion_matrices(results, model_name, save_dir=SAVE_DIR):
    plt.figure(figsize=(5, 4))
    sns.heatmap(results['pixel_cm'], annot=True, fmt='d', cmap='Blues',
                xticklabels=['Pred 0', 'Pred 1'],
                yticklabels=['True 0', 'True 1'])
    plt.title(f'{model_name} — Pixel Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.savefig(f'{save_dir}/{model_name}_pixel_cm.png', dpi=150, bbox_inches='tight')
    plt.show()

    plt.figure(figsize=(5, 4))
    sns.heatmap(results['image_cm'], annot=True, fmt='d', cmap='Blues',
                xticklabels=['Pred Authentic', 'Pred Fake'],
                yticklabels=['True Authentic', 'True Fake'])
    plt.title(f'{model_name} — Image Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.savefig(f'{save_dir}/{model_name}_image_cm.png', dpi=150, bbox_inches='tight')
    plt.show()


print("✓ Functions ready")
# Out:
# ✓ Functions ready

# %%
# Cell 5 — Reusable experiment runner

def build_unet_model(encoder_name, encoder_depth=5, decoder_channels=None, encoder_weights='imagenet'):
    """
    Builds SMP U-Net. Falls back to encoder_weights=None if pretrained loading fails.
    """
    if decoder_channels is None:
        decoder_channels = (256, 128, 64, 32, 16) if encoder_depth == 5 else (256, 128, 64, 32)

    try:
        model = smp.Unet(
            encoder_name=encoder_name,
            encoder_weights=encoder_weights,
            encoder_depth=encoder_depth,
            decoder_channels=decoder_channels,
            in_channels=3,
            classes=1,
            activation=None
        )
        return model
    except Exception as e:
        print(f"⚠️ Could not build/load with encoder_weights='{encoder_weights}'.")
        print("Reason:", repr(e))
        print("Retrying with encoder_weights=None...")

        model = smp.Unet(
            encoder_name=encoder_name,
            encoder_weights=None,
            encoder_depth=encoder_depth,
            decoder_channels=decoder_channels,
            in_channels=3,
            classes=1,
            activation=None
        )
        return model


def run_experiment(
    model_name,
    encoder_name,
    augment=False,
    batch_size=BATCH_SIZE,
    pos_weight=None,
    encoder_depth=5,
    decoder_channels=None,
    remove_checkpoint_after_eval=True
):
    print(f"\n{'='*70}")
    print(f"TRAINING: {model_name}")
    print(f"Encoder: {encoder_name}")
    print(f"Config: {IMG_SIZE}x{IMG_SIZE}, augmentation={augment}, pos_weight={pos_weight}")
    print(f"Batch size: {batch_size}")
    print(f"{'='*70}")

    train_loader, val_loader, test_loader = make_loaders(
        augment=augment,
        batch_size=batch_size,
        include_authentic=True
    )

    model = build_unet_model(
        encoder_name=encoder_name,
        encoder_depth=encoder_depth,
        decoder_channels=decoder_channels,
        encoder_weights='imagenet'
    ).to(DEVICE)

    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    model_size = total_params * 4 / 1024**2

    print(f"Parameters: {total_params:,}")
    print(f"Trainable: {trainable_params:,}")
    print(f"Estimated fp32 model size: {model_size:.1f} MB")

    criterion = DiceBCELoss(pos_weight=pos_weight).to(DEVICE)

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=LR,
        weight_decay=WEIGHT_DECAY
    )

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=NUM_EPOCHS,
        eta_min=1e-6
    )

    scaler = GradScaler(device=DEVICE.type, enabled=USE_AMP)

    history = {
        'train_loss': [],
        'val_loss': [],
        'train_acc': [],
        'val_acc': [],
        'val_f1': [],
        'val_iou': [],
        'val_precision': [],
        'val_recall': [],
        'epoch_time': []
    }

    best_val_iou = -1.0
    best_val_f1 = -1.0
    best_epoch = 0
    total_time = 0.0
    patience_counter = 0

    best_ckpt_path = f'{SAVE_DIR}/best_{model_name}.pth'

    for epoch in range(1, NUM_EPOCHS + 1):
        tl, ta, et = train_one_epoch(model, train_loader, criterion, optimizer, scaler, DEVICE)
        vl, va = validate(model, val_loader, criterion, DEVICE)

        val_eval = full_evaluation(model, val_loader, DEVICE, threshold=BINARY_THRESHOLD)
        val_iou = val_eval['pixel']['iou']
        val_f1 = val_eval['pixel']['f1']

        scheduler.step()
        total_time += et

        history['train_loss'].append(tl)
        history['val_loss'].append(vl)
        history['train_acc'].append(ta)
        history['val_acc'].append(va)
        history['val_f1'].append(val_f1)
        history['val_iou'].append(val_iou)
        history['val_precision'].append(val_eval['pixel']['precision'])
        history['val_recall'].append(val_eval['pixel']['recall'])
        history['epoch_time'].append(et)

        if val_iou > best_val_iou:
            best_val_iou = val_iou
            best_val_f1 = val_f1
            best_epoch = epoch
            patience_counter = 0

            torch.save({
                'model_state_dict': model.state_dict(),
                'epoch': epoch,
                'best_val_iou': best_val_iou,
                'best_val_f1': best_val_f1,
                'encoder_name': encoder_name,
                'encoder_depth': encoder_depth,
                'model_name': model_name,
            }, best_ckpt_path)
            improved = "YES"
        else:
            patience_counter += 1
            improved = "NO"

        print(f"Epoch {epoch:>3}/{NUM_EPOCHS} | "
              f"TrLoss: {tl:.4f} TrAcc: {ta:.4f} | "
              f"VlLoss: {vl:.4f} VlAcc: {va:.4f} | "
              f"ValF1: {val_f1:.4f} ValIoU: {val_iou:.4f} | "
              f"{et:.1f}s | Improved: {improved} | Patience: {patience_counter}/{PATIENCE}")

        if patience_counter >= PATIENCE:
            print(f"Early stopping at epoch {epoch}.")
            break

    history['total_time'] = total_time
    history['best_epoch'] = best_epoch
    history['best_val_iou'] = best_val_iou
    history['best_val_f1'] = best_val_f1

    print(f"\nTraining complete.")
    print(f"Best epoch: {best_epoch}")
    print(f"Best val IoU: {best_val_iou:.4f}")
    print(f"Best val F1: {best_val_f1:.4f}")
    print(f"Total time: {total_time:.0f}s")

    ckpt = torch.load(best_ckpt_path, map_location=DEVICE)
    model.load_state_dict(ckpt['model_state_dict'])
    print(f"Loaded best checkpoint from epoch {ckpt['epoch']} (val IoU: {ckpt['best_val_iou']:.4f})")

    results = full_evaluation(model, test_loader, DEVICE, threshold=BINARY_THRESHOLD)

    print(f"\n{'='*60}")
    print(f"TEST SET — {model_name}")
    print(f"{'='*60}")
    print(f"Pixel Accuracy:  {results['pixel']['accuracy']:.4f}")
    print(f"Pixel Precision: {results['pixel']['precision']:.4f}")
    print(f"Pixel Recall:    {results['pixel']['recall']:.4f}")
    print(f"Pixel F1:        {results['pixel']['f1']:.4f}")
    print(f"IoU:             {results['pixel']['iou']:.4f}")
    print(f"Dice:            {results['pixel']['dice']:.4f}")
    print(f"Image Accuracy:  {results['image']['accuracy']:.4f}")
    print(f"Image Precision: {results['image']['precision']:.4f}")
    print(f"Image Recall:    {results['image']['recall']:.4f}")
    print(f"Image F1:        {results['image']['f1']:.4f}")
    print(f"{'='*60}")
    print(f"Parameters: {total_params:,}")
    print(f"Model size: {model_size:.1f} MB")
    print(f"Total training time: {total_time:.0f}s")
    print(f"Avg epoch time: {np.mean(history['epoch_time']):.1f}s")

    plot_history(history, model_name, SAVE_DIR)
    plot_confusion_matrices(results, model_name, SAVE_DIR)

    ckpt_size_mb = os.path.getsize(best_ckpt_path) / 1024**2 if os.path.exists(best_ckpt_path) else None

    save_data = {
        'model': model_name,
        'encoder_name': encoder_name,
        'config': {
            'image_size': IMG_SIZE,
            'augmentation': augment,
            'pos_weight': pos_weight,
            'batch_size': batch_size,
            'num_epochs_requested': NUM_EPOCHS,
            'num_epochs_completed': len(history['train_loss']),
            'lr': LR,
            'weight_decay': WEIGHT_DECAY,
            'threshold': BINARY_THRESHOLD,
        },
        'test_results': {
            'pixel_metrics': results['pixel'],
            'image_metrics': results['image'],
            'pixel_cm': results['pixel_cm'].tolist(),
            'image_cm': results['image_cm'].tolist(),
        },
        'history': history,
        'model_info': {
            'total_params': total_params,
            'trainable_params': trainable_params,
            'model_size_mb': model_size,
            'checkpoint_size_mb': ckpt_size_mb,
        },
    }

    json_path = f'{SAVE_DIR}/{model_name}_results.json'
    with open(json_path, 'w') as f:
        json.dump(save_data, f, indent=2, default=str)

    print(f"✓ Saved {json_path}")

    print(f"\n{'='*60}")
    print("COPY-PASTE BACKUP:")
    print(json.dumps({
        'model': model_name,
        'pixel': results['pixel'],
        'image': results['image'],
        'params': total_params,
        'size_mb': model_size,
        'best_epoch': best_epoch,
        'total_time': total_time,
    }, indent=2))
    print(f"{'='*60}")

    if remove_checkpoint_after_eval and os.path.exists(best_ckpt_path):
        os.remove(best_ckpt_path)
        print("✓ Checkpoint removed to save disk")

    del model
    gc.collect()
    if DEVICE.type == 'cuda':
        torch.cuda.empty_cache()

    return save_data

# %%
# Cell 6 — EfficientNetV2-L training with augmentation

effnetv2l_aug_results = run_experiment(
    model_name='EfficientNetV2L_384_aug',
    encoder_name='tu-tf_efficientnetv2_l',
    augment=True,
    batch_size=4,
    pos_weight=3.0,      # change to POS_WEIGHT if recall is very low
    encoder_depth=5
)
# Out:
# ======================================================================
# TRAINING: EfficientNetV2L_384_aug
# Encoder: tu-tf_efficientnetv2_l
# Config: 384x384, augmentation=True, pos_weight=3.0
# Batch size: 4
# ======================================================================
# Building datasets | augmentation=True | batch_size=4
#   training: 7559 total (5459 forged, 2100 authentic)
#     fake files found: 5459 | masks found: 4200 | unmatched fakes: 0
#   validation: 1023 total (682 forged, 341 authentic)
#     fake files found: 682 | masks found: 682 | unmatched fakes: 0
#   testing: 1029 total (686 forged, 343 authentic)
#     fake files found: 686 | masks found: 686 | unmatched fakes: 0
# Unexpected keys (bn2.num_batches_tracked, bn2.bias, bn2.running_mean, bn2.running_var, bn2.weight, classifier.bias, classifier.weight, conv_head.weight) found while loading pretrained weights. This may be expected if model is being adapted.
# Parameters: 119,739,313
# Trainable: 119,739,313
# Estimated fp32 model size: 456.8 MB
# Epoch   1/20 | TrLoss: 0.5357 TrAcc: 0.9306 | VlLoss: 0.4752 VlAcc: 0.9640 | ValF1: 0.5544 ValIoU: 0.3835 | 540.9s | Improved: YES | Patience: 0/5
# Epoch   2/20 | TrLoss: 0.4289 TrAcc: 0.9641 | VlLoss: 0.4415 VlAcc: 0.9680 | ValF1: 0.6280 ValIoU: 0.4578 | 540.3s | Improved: YES | Patience: 0/5
# Epoch   3/20 | TrLoss: 0.3878 TrAcc: 0.9723 | VlLoss: 0.4396 VlAcc: 0.9698 | ValF1: 0.6405 ValIoU: 0.4712 | 540.2s | Improved: YES | Patience: 0/5
# Epoch   4/20 | TrLoss: 0.3567 TrAcc: 0.9761 | VlLoss: 0.3973 VlAcc: 0.9734 | ValF1: 0.7138 ValIoU: 0.5549 | 539.6s | Improved: YES | Patience: 0/5
# Epoch   5/20 | TrLoss: 0.3354 TrAcc: 0.9794 | VlLoss: 0.4002 VlAcc: 0.9732 | ValF1: 0.7131 ValIoU: 0.5541 | 538.5s | Improved: NO | Patience: 1/5
# Epoch   6/20 | TrLoss: 0.3188 TrAcc: 0.9813 | VlLoss: 0.3886 VlAcc: 0.9753 | ValF1: 0.7286 ValIoU: 0.5731 | 537.8s | Improved: YES | Patience: 0/5
# Epoch   7/20 | TrLoss: 0.2994 TrAcc: 0.9836 | VlLoss: 0.3939 VlAcc: 0.9763 | ValF1: 0.7332 ValIoU: 0.5788 | 539.3s | Improved: YES | Patience: 0/5
# Epoch   8/20 | TrLoss: 0.2840 TrAcc: 0.9859 | VlLoss: 0.3737 VlAcc: 0.9783 | ValF1: 0.7657 ValIoU: 0.6203 | 538.7s | Improved: YES | Patience: 0/5
# Epoch   9/20 | TrLoss: 0.2682 TrAcc: 0.9869 | VlLoss: 0.3562 VlAcc: 0.9801 | ValF1: 0.7673 ValIoU: 0.6225 | 539.4s | Improved: YES | Patience: 0/5
# Epoch  10/20 | TrLoss: 0.2089 TrAcc: 0.9882 | VlLoss: 0.4044 VlAcc: 0.9791 | ValF1: 0.7455 ValIoU: 0.5942 | 538.0s | Improved: NO | Patience: 1/5
# Epoch  11/20 | TrLoss: 0.1966 TrAcc: 0.9893 | VlLoss: 0.3601 VlAcc: 0.9805 | ValF1: 0.7639 ValIoU: 0.6180 | 536.5s | Improved: NO | Patience: 2/5
# Epoch  12/20 | TrLoss: 0.1786 TrAcc: 0.9903 | VlLoss: 0.3032 VlAcc: 0.9798 | ValF1: 0.7822 ValIoU: 0.6424 | 536.4s | Improved: YES | Patience: 0/5
# Epoch  13/20 | TrLoss: 0.1588 TrAcc: 0.9912 | VlLoss: 0.3532 VlAcc: 0.9828 | ValF1: 0.7927 ValIoU: 0.6566 | 536.0s | Improved: YES | Patience: 0/5
# Epoch  14/20 | TrLoss: 0.1518 TrAcc: 0.9915 | VlLoss: 0.3412 VlAcc: 0.9836 | ValF1: 0.8067 ValIoU: 0.6760 | 535.7s | Improved: YES | Patience: 0/5
# Epoch  15/20 | TrLoss: 0.1388 TrAcc: 0.9920 | VlLoss: 0.3717 VlAcc: 0.9825 | ValF1: 0.7901 ValIoU: 0.6530 | 535.8s | Improved: NO | Patience: 1/5
# Epoch  16/20 | TrLoss: 0.1350 TrAcc: 0.9924 | VlLoss: 0.3294 VlAcc: 0.9831 | ValF1: 0.8005 ValIoU: 0.6674 | 535.5s | Improved: NO | Patience: 2/5
# Epoch  17/20 | TrLoss: 0.1240 TrAcc: 0.9930 | VlLoss: 0.3588 VlAcc: 0.9830 | ValF1: 0.7952 ValIoU: 0.6601 | 536.0s | Improved: NO | Patience: 3/5
# Epoch  18/20 | TrLoss: 0.1184 TrAcc: 0.9931 | VlLoss: 0.3170 VlAcc: 0.9840 | ValF1: 0.8121 ValIoU: 0.6836 | 536.6s | Improved: YES | Patience: 0/5
# Epoch  19/20 | TrLoss: 0.1192 TrAcc: 0.9933 | VlLoss: 0.3459 VlAcc: 0.9835 | ValF1: 0.8015 ValIoU: 0.6688 | 535.2s | Improved: NO | Patience: 1/5
# Epoch  20/20 | TrLoss: 0.1136 TrAcc: 0.9934 | VlLoss: 0.3375 VlAcc: 0.9838 | ValF1: 0.8059 ValIoU: 0.6748 | 535.2s | Improved: NO | Patience: 2/5
#
# Training complete.
# Best epoch: 18
# Best val IoU: 0.6836
# Best val F1: 0.8121
# Total time: 10752s
# Loaded best checkpoint from epoch 18 (val IoU: 0.6836)
#
# ============================================================
# TEST SET — EfficientNetV2L_384_aug
# ============================================================
# Pixel Accuracy:  0.9832
# Pixel Precision: 0.8519
# Pixel Recall:    0.7283
# Pixel F1:        0.7853
# IoU:             0.6465
# Dice:            0.7853
# Image Accuracy:  0.7143
# Image Precision: 0.9000
# Image Recall:    0.6429
# Image F1:        0.7500
# ============================================================
# Parameters: 119,739,313
# Model size: 456.8 MB
# Total training time: 10752s
# Avg epoch time: 537.6s
# ✓ Saved /kaggle/working/EfficientNetV2L_384_aug_results.json
#
# ============================================================
# COPY-PASTE BACKUP:
# {
#   "model": "EfficientNetV2L_384_aug",
#   "pixel": {
#     "accuracy": 0.9831800593656361,
#     "precision": 0.8519148611451361,
#     "recall": 0.7282948361136334,
#     "f1": 0.7852694377593313,
#     "iou": 0.6464556588522286,
#     "dice": 0.7852694427287322
#   },
#   "image": {
#     "accuracy": 0.7142857142857143,
#     "precision": 0.9,
#     "recall": 0.6428571428571429,
#     "f1": 0.75
#   },
#   "params": 119739313,
#   "size_mb": 456.769229888916,
#   "best_epoch": 18,
#   "total_time": 10751.543783187866
# }
# ============================================================
# ✓ Checkpoint removed to save disk

# %%
# Cell 7 — EfficientNet-B4 training with augmentation

effnetb4_aug_results = run_experiment(
    model_name='EfficientNetB4_384_aug',
    encoder_name='tu-tf_efficientnet_b4',
    augment=True,
    batch_size=8,         # try 8 if Kaggle GPU memory allows it
    pos_weight=3.0,      # change to POS_WEIGHT if recall is very low
    encoder_depth=5
)
# Out:
# ======================================================================
# TRAINING: EfficientNetB4_384_aug
# Encoder: tu-tf_efficientnet_b4
# Config: 384x384, augmentation=True, pos_weight=3.0
# Batch size: 8
# ======================================================================
# Building datasets | augmentation=True | batch_size=8
#   training: 7559 total (5459 forged, 2100 authentic)
#     fake files found: 5459 | masks found: 4200 | unmatched fakes: 0
#   validation: 1023 total (682 forged, 341 authentic)
#     fake files found: 682 | masks found: 682 | unmatched fakes: 0
#   testing: 1029 total (686 forged, 343 authentic)
#     fake files found: 686 | masks found: 686 | unmatched fakes: 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/77.9M [00:00<?, ?B/s]
# Unexpected keys (bn2.num_batches_tracked, bn2.bias, bn2.running_mean, bn2.running_var, bn2.weight, classifier.bias, classifier.weight, conv_head.weight) found while loading pretrained weights. This may be expected if model is being adapted.
# Parameters: 19,412,377
# Trainable: 19,412,377
# Estimated fp32 model size: 74.1 MB
# Epoch   1/20 | TrLoss: 0.5969 TrAcc: 0.9123 | VlLoss: 0.5415 VlAcc: 0.9486 | ValF1: 0.4186 ValIoU: 0.2647 | 300.6s | Improved: YES | Patience: 0/5
# Epoch   2/20 | TrLoss: 0.4801 TrAcc: 0.9512 | VlLoss: 0.5618 VlAcc: 0.9542 | ValF1: 0.4247 ValIoU: 0.2696 | 223.0s | Improved: YES | Patience: 0/5
# Epoch   3/20 | TrLoss: 0.4320 TrAcc: 0.9609 | VlLoss: 0.5558 VlAcc: 0.9584 | ValF1: 0.4502 ValIoU: 0.2905 | 224.2s | Improved: YES | Patience: 0/5
# Epoch   4/20 | TrLoss: 0.3984 TrAcc: 0.9670 | VlLoss: 0.5603 VlAcc: 0.9552 | ValF1: 0.4696 ValIoU: 0.3069 | 223.4s | Improved: YES | Patience: 0/5
# Epoch   5/20 | TrLoss: 0.3706 TrAcc: 0.9715 | VlLoss: 0.5837 VlAcc: 0.9551 | ValF1: 0.4607 ValIoU: 0.2993 | 223.7s | Improved: NO | Patience: 1/5
# Epoch   6/20 | TrLoss: 0.3475 TrAcc: 0.9752 | VlLoss: 0.6015 VlAcc: 0.9574 | ValF1: 0.4555 ValIoU: 0.2949 | 223.3s | Improved: NO | Patience: 2/5
# Epoch   7/20 | TrLoss: 0.3294 TrAcc: 0.9782 | VlLoss: 0.6175 VlAcc: 0.9591 | ValF1: 0.4589 ValIoU: 0.2978 | 223.6s | Improved: NO | Patience: 3/5
# Epoch   8/20 | TrLoss: 0.3124 TrAcc: 0.9804 | VlLoss: 0.5926 VlAcc: 0.9564 | ValF1: 0.4793 ValIoU: 0.3152 | 222.9s | Improved: YES | Patience: 0/5
# Epoch   9/20 | TrLoss: 0.2986 TrAcc: 0.9825 | VlLoss: 0.6794 VlAcc: 0.9605 | ValF1: 0.4344 ValIoU: 0.2775 | 223.5s | Improved: NO | Patience: 1/5
# Epoch  10/20 | TrLoss: 0.2879 TrAcc: 0.9836 | VlLoss: 0.6686 VlAcc: 0.9591 | ValF1: 0.4595 ValIoU: 0.2982 | 223.2s | Improved: NO | Patience: 2/5
# Epoch  11/20 | TrLoss: 0.2635 TrAcc: 0.9853 | VlLoss: 0.8181 VlAcc: 0.9617 | ValF1: 0.4530 ValIoU: 0.2928 | 223.8s | Improved: NO | Patience: 3/5
# Epoch  12/20 | TrLoss: 0.2270 TrAcc: 0.9860 | VlLoss: 0.8162 VlAcc: 0.9615 | ValF1: 0.4600 ValIoU: 0.2987 | 223.5s | Improved: NO | Patience: 4/5
# Epoch  13/20 | TrLoss: 0.2149 TrAcc: 0.9866 | VlLoss: 0.8197 VlAcc: 0.9623 | ValF1: 0.4679 ValIoU: 0.3054 | 222.6s | Improved: NO | Patience: 5/5
# Early stopping at epoch 13.
#
# Training complete.
# Best epoch: 8
# Best val IoU: 0.3152
# Best val F1: 0.4793
# Total time: 2981s
# Loaded best checkpoint from epoch 8 (val IoU: 0.3152)
#
# ============================================================
# TEST SET — EfficientNetB4_384_aug
# ============================================================
# Pixel Accuracy:  0.9561
# Pixel Precision: 0.4768
# Pixel Recall:    0.3948
# Pixel F1:        0.4319
# IoU:             0.2754
# Dice:            0.4319
# Image Accuracy:  0.6696
# Image Precision: 0.6810
# Image Recall:    0.9490
# Image F1:        0.7929
# ============================================================
# Parameters: 19,412,377
# Model size: 74.1 MB
# Total training time: 2981s
# Avg epoch time: 229.3s
# ✓ Saved /kaggle/working/EfficientNetB4_384_aug_results.json
#
# ============================================================
# COPY-PASTE BACKUP:
# {
#   "model": "EfficientNetB4_384_aug",
#   "pixel": {
#     "accuracy": 0.9561457031039102,
#     "precision": 0.4767605820960977,
#     "recall": 0.3947593444514165,
#     "f1": 0.4319022134917519,
#     "iou": 0.2754306673528217,
#     "dice": 0.43190221844748766
#   },
#   "image": {
#     "accuracy": 0.6695821185617103,
#     "precision": 0.6809623430962343,
#     "recall": 0.9489795918367347,
#     "f1": 0.7929354445797807
#   },
#   "params": 19412377,
#   "size_mb": 74.05234146118164,
#   "best_epoch": 8,
#   "total_time": 2981.3250834941864
# }
# ============================================================
# ✓ Checkpoint removed to save disk

# %%
# Cell 8 — Swin-B 384 smoke test
# Swin 384 uses a 4-stage transformer encoder, so we use encoder_depth=4.

SWIN_ENCODER = 'tu-swin_base_patch4_window12_384'

print("Testing Swin-B 384 encoder with a dummy forward pass...")

swin_test_model = build_unet_model(
    encoder_name=SWIN_ENCODER,
    encoder_depth=4,
    decoder_channels=(256, 128, 64, 32),
    encoder_weights='imagenet'
).to(DEVICE)

swin_test_model.eval()

with torch.no_grad():
    dummy = torch.randn(1, 3, IMG_SIZE, IMG_SIZE).to(DEVICE)
    with autocast(device_type=DEVICE.type, enabled=USE_AMP):
        dummy_out = swin_test_model(dummy)

print("Swin dummy output shape:", dummy_out.shape)

del swin_test_model, dummy, dummy_out
gc.collect()
if DEVICE.type == 'cuda':
    torch.cuda.empty_cache()

print("✓ Swin-B 384 smoke test passed")
# Out:
# Testing Swin-B 384 encoder with a dummy forward pass...
# model.safetensors:   0%|          | 0.00/365M [00:00<?, ?B/s]
# Swin dummy output shape: torch.Size([1, 1, 384, 384])
# ✓ Swin-B 384 smoke test passed

# %%
# Cell 9 — Swin-B 384 baseline without augmentation

swin_baseline_results = run_experiment(
    model_name='SwinB_384_baseline_noaug',
    encoder_name=SWIN_ENCODER,
    augment=False,
    batch_size=8,
    pos_weight=3.0,
    encoder_depth=4,
    decoder_channels=(256, 128, 64, 32)
)
# Out:
# ======================================================================
# TRAINING: SwinB_384_baseline_noaug
# Encoder: tu-swin_base_patch4_window12_384
# Config: 384x384, augmentation=False, pos_weight=3.0
# Batch size: 8
# ======================================================================
# Building datasets | augmentation=False | batch_size=8
#   training: 7559 total (5459 forged, 2100 authentic)
#     fake files found: 5459 | masks found: 4200 | unmatched fakes: 0
#   validation: 1023 total (682 forged, 341 authentic)
#     fake files found: 682 | masks found: 682 | unmatched fakes: 0
#   testing: 1029 total (686 forged, 343 authentic)
#     fake files found: 686 | masks found: 686 | unmatched fakes: 0
# Parameters: 62,638,553
# Trainable: 62,638,553
# Estimated fp32 model size: 238.9 MB
# Epoch   1/20 | TrLoss: 0.4604 TrAcc: 0.9574 | VlLoss: 0.3611 VlAcc: 0.9698 | ValF1: 0.7240 ValIoU: 0.5673 | 553.5s | Improved: YES | Patience: 0/5
# Epoch   2/20 | TrLoss: 0.3222 TrAcc: 0.9812 | VlLoss: 0.3516 VlAcc: 0.9679 | ValF1: 0.7217 ValIoU: 0.5645 | 533.3s | Improved: NO | Patience: 1/5
# Epoch   3/20 | TrLoss: 0.2735 TrAcc: 0.9872 | VlLoss: 0.3465 VlAcc: 0.9787 | ValF1: 0.7878 ValIoU: 0.6498 | 533.4s | Improved: YES | Patience: 0/5
# Epoch   4/20 | TrLoss: 0.2153 TrAcc: 0.9893 | VlLoss: 0.2987 VlAcc: 0.9827 | ValF1: 0.8055 ValIoU: 0.6743 | 529.2s | Improved: YES | Patience: 0/5
# Epoch   5/20 | TrLoss: 0.1580 TrAcc: 0.9912 | VlLoss: 0.3037 VlAcc: 0.9829 | ValF1: 0.8039 ValIoU: 0.6721 | 524.3s | Improved: NO | Patience: 1/5
# Epoch   6/20 | TrLoss: 0.1296 TrAcc: 0.9929 | VlLoss: 0.2390 VlAcc: 0.9865 | ValF1: 0.8520 ValIoU: 0.7421 | 525.0s | Improved: YES | Patience: 0/5
# Epoch   7/20 | TrLoss: 0.1008 TrAcc: 0.9944 | VlLoss: 0.2685 VlAcc: 0.9868 | ValF1: 0.8482 ValIoU: 0.7364 | 522.8s | Improved: NO | Patience: 1/5
# Epoch   8/20 | TrLoss: 0.0800 TrAcc: 0.9954 | VlLoss: 0.2434 VlAcc: 0.9886 | ValF1: 0.8686 ValIoU: 0.7678 | 520.1s | Improved: YES | Patience: 0/5
# Epoch   9/20 | TrLoss: 0.0643 TrAcc: 0.9961 | VlLoss: 0.2018 VlAcc: 0.9898 | ValF1: 0.8874 ValIoU: 0.7975 | 518.9s | Improved: YES | Patience: 0/5
# Epoch  10/20 | TrLoss: 0.0513 TrAcc: 0.9968 | VlLoss: 0.2457 VlAcc: 0.9897 | ValF1: 0.8804 ValIoU: 0.7864 | 520.8s | Improved: NO | Patience: 1/5
# Epoch  11/20 | TrLoss: 0.0424 TrAcc: 0.9972 | VlLoss: 0.2146 VlAcc: 0.9904 | ValF1: 0.8908 ValIoU: 0.8031 | 521.3s | Improved: YES | Patience: 0/5
# Epoch  12/20 | TrLoss: 0.0361 TrAcc: 0.9976 | VlLoss: 0.2021 VlAcc: 0.9904 | ValF1: 0.8927 ValIoU: 0.8061 | 521.5s | Improved: YES | Patience: 0/5
# Epoch  13/20 | TrLoss: 0.0303 TrAcc: 0.9980 | VlLoss: 0.1987 VlAcc: 0.9911 | ValF1: 0.9001 ValIoU: 0.8184 | 521.7s | Improved: YES | Patience: 0/5
# Epoch  14/20 | TrLoss: 0.0269 TrAcc: 0.9982 | VlLoss: 0.2156 VlAcc: 0.9909 | ValF1: 0.8961 ValIoU: 0.8118 | 522.2s | Improved: NO | Patience: 1/5
# Epoch  15/20 | TrLoss: 0.0228 TrAcc: 0.9984 | VlLoss: 0.2143 VlAcc: 0.9912 | ValF1: 0.8996 ValIoU: 0.8175 | 525.4s | Improved: NO | Patience: 2/5
# Epoch  16/20 | TrLoss: 0.0205 TrAcc: 0.9986 | VlLoss: 0.2104 VlAcc: 0.9912 | ValF1: 0.9001 ValIoU: 0.8184 | 525.2s | Improved: NO | Patience: 3/5
# Epoch  17/20 | TrLoss: 0.0180 TrAcc: 0.9987 | VlLoss: 0.2168 VlAcc: 0.9912 | ValF1: 0.8998 ValIoU: 0.8179 | 527.1s | Improved: NO | Patience: 4/5
# Epoch  18/20 | TrLoss: 0.0160 TrAcc: 0.9988 | VlLoss: 0.2116 VlAcc: 0.9913 | ValF1: 0.9007 ValIoU: 0.8194 | 527.4s | Improved: YES | Patience: 0/5
# Epoch  19/20 | TrLoss: 0.0152 TrAcc: 0.9989 | VlLoss: 0.2233 VlAcc: 0.9912 | ValF1: 0.8990 ValIoU: 0.8165 | 527.8s | Improved: NO | Patience: 1/5
# Epoch  20/20 | TrLoss: 0.0146 TrAcc: 0.9989 | VlLoss: 0.2197 VlAcc: 0.9913 | ValF1: 0.9002 ValIoU: 0.8185 | 527.7s | Improved: NO | Patience: 2/5
#
# Training complete.
# Best epoch: 18
# Best val IoU: 0.8194
# Best val F1: 0.9007
# Total time: 10529s
# Loaded best checkpoint from epoch 18 (val IoU: 0.8194)
#
# ============================================================
# TEST SET — SwinB_384_baseline_noaug
# ============================================================
# Pixel Accuracy:  0.9918
# Pixel Precision: 0.9229
# Pixel Recall:    0.8803
# Pixel F1:        0.9011
# IoU:             0.8200
# Dice:            0.9011
# Image Accuracy:  0.8134
# Image Precision: 0.9364
# Image Recall:    0.7726
# Image F1:        0.8466
# ============================================================
# Parameters: 62,638,553
# Model size: 238.9 MB
# Total training time: 10529s
# Avg epoch time: 526.4s
# ✓ Saved /kaggle/working/SwinB_384_baseline_noaug_results.json
#
# ============================================================
# COPY-PASTE BACKUP:
# {
#   "model": "SwinB_384_baseline_noaug",
#   "pixel": {
#     "accuracy": 0.9918381938433856,
#     "precision": 0.9228954262161753,
#     "recall": 0.8802689465298489,
#     "f1": 0.9010783402402138,
#     "iou": 0.8199659560190365,
#     "dice": 0.9010783452374204
#   },
#   "image": {
#     "accuracy": 0.8134110787172012,
#     "precision": 0.9363957597173145,
#     "recall": 0.7725947521865889,
#     "f1": 0.8466453674121406
#   },
#   "params": 62638553,
#   "size_mb": 238.94711685180664,
#   "best_epoch": 18,
#   "total_time": 10528.757071256638
# }
# ============================================================
# ✓ Checkpoint removed to save disk

# %%
# ============================================================
# Custom CvT / ConViT segmentation support
# Add this AFTER Cell 5
# ============================================================

# !pip install -q transformers

import math
import timm
from transformers import AutoModel


class SimpleTransformerSegDecoder(nn.Module):
    """
    Lightweight decoder for single-scale transformer features.
    This is not a full U-Net decoder, because ConViT/CvT do not expose
    SMP-style multi-scale features in this setup.
    """
    def __init__(self, in_channels, hidden_channels=256):
        super().__init__()

        self.decoder = nn.Sequential(
            nn.Conv2d(in_channels, hidden_channels, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(hidden_channels),
            nn.ReLU(inplace=True),

            nn.Conv2d(hidden_channels, hidden_channels // 2, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(hidden_channels // 2),
            nn.ReLU(inplace=True),

            nn.Conv2d(hidden_channels // 2, hidden_channels // 4, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(hidden_channels // 4),
            nn.ReLU(inplace=True),

            nn.Conv2d(hidden_channels // 4, 1, kernel_size=1)
        )

    def forward(self, feat, out_size):
        x = self.decoder(feat)
        x = F.interpolate(x, size=out_size, mode="bilinear", align_corners=False)
        return x


class HFCvTSeg(nn.Module):
    """
    CvT segmentation wrapper using Hugging Face CvT.
    Recommended:
      - microsoft/cvt-13        for 224
      - microsoft/cvt-13-384    for 384
    """
    def __init__(self, model_name="microsoft/cvt-13-384", img_size=384):
        super().__init__()

        self.model_name = model_name
        self.img_size = img_size

        self.backbone = AutoModel.from_pretrained(model_name)

        with torch.no_grad():
            dummy = torch.zeros(1, 3, img_size, img_size)
            feat = self.extract_features(dummy)

        in_channels = feat.shape[1]
        self.decoder = SimpleTransformerSegDecoder(in_channels=in_channels)

        print(f"✓ Built CvT segmentation model: {model_name}")
        print(f"Feature shape from dummy input: {feat.shape}")

    def extract_features(self, x):
        outputs = self.backbone(
            pixel_values=x,
            output_hidden_states=True,
            return_dict=True
        )

        if outputs.hidden_states is not None:
            feat = outputs.hidden_states[-1]
        else:
            feat = outputs.last_hidden_state

        # Case 1: already feature map, usually B, C, H, W
        if feat.ndim == 4:
            # If accidentally NHWC, convert to NCHW
            if feat.shape[1] < feat.shape[-1]:
                feat = feat.permute(0, 3, 1, 2).contiguous()
            return feat

        # Case 2: token sequence, B, N, C
        if feat.ndim == 3:
            B, N, C = feat.shape

            # Remove CLS token if present
            root = int(math.sqrt(N))
            if root * root != N:
                root = int(math.sqrt(N - 1))
                if root * root == N - 1:
                    feat = feat[:, 1:, :]
                    N = N - 1

            H = W = int(math.sqrt(N))
            feat = feat.transpose(1, 2).reshape(B, C, H, W)
            return feat

        raise RuntimeError(f"Unexpected CvT feature shape: {feat.shape}")

    def forward(self, x):
        feat = self.extract_features(x)
        logits = self.decoder(feat, out_size=x.shape[-2:])
        return logits


class ConViTTinySeg(nn.Module):
    """
    ConViT-Tiny segmentation wrapper using timm.
    Recommended:
      - 224 with pretrained=True
      - 384 with pretrained=False if pretrained loading fails
    """
    def __init__(self, img_size=224, pretrained=True):
        super().__init__()

        self.img_size = img_size

        try:
            self.backbone = timm.create_model(
                "convit_tiny",
                pretrained=pretrained,
                img_size=img_size,
                num_classes=0
            )
        except Exception as e:
            print("⚠️ Could not load ConViT with requested pretrained/img_size.")
            print("Reason:", repr(e))
            print("Retrying ConViT-Tiny with pretrained=False...")
            self.backbone = timm.create_model(
                "convit_tiny",
                pretrained=False,
                img_size=img_size,
                num_classes=0
            )

        patch_size = self.backbone.patch_embed.patch_size
        if isinstance(patch_size, tuple):
            self.patch_h, self.patch_w = patch_size
        else:
            self.patch_h = self.patch_w = patch_size

        embed_dim = self.backbone.embed_dim
        self.decoder = SimpleTransformerSegDecoder(in_channels=embed_dim)

        print(f"✓ Built ConViT-Tiny segmentation model")
        print(f"Image size: {img_size}, patch size: {self.patch_h}x{self.patch_w}, embed_dim: {embed_dim}")

    def interpolate_pos_embed(self, pos_embed, H_new, W_new):
        B, N, C = pos_embed.shape
        H_old = W_old = int(math.sqrt(N))

        pos_embed = pos_embed.reshape(1, H_old, W_old, C).permute(0, 3, 1, 2)
        pos_embed = F.interpolate(
            pos_embed,
            size=(H_new, W_new),
            mode="bicubic",
            align_corners=False
        )
        pos_embed = pos_embed.permute(0, 2, 3, 1).reshape(1, H_new * W_new, C)

        return pos_embed

    def forward_features_as_map(self, x):
        B, _, H, W = x.shape

        x_tokens = self.backbone.patch_embed(x)

        H_patch = H // self.patch_h
        W_patch = W // self.patch_w

        if getattr(self.backbone, "use_pos_embed", True):
            pos_embed = self.backbone.pos_embed

            if pos_embed.shape[1] != x_tokens.shape[1]:
                pos_embed = self.interpolate_pos_embed(pos_embed, H_patch, W_patch)

            x_tokens = x_tokens + pos_embed

        x_tokens = self.backbone.pos_drop(x_tokens)

        cls_tokens = self.backbone.cls_token.expand(B, -1, -1)
        cls_inserted = False

        for i, block in enumerate(self.backbone.blocks):
            if i == self.backbone.local_up_to_layer:
                x_tokens = torch.cat((cls_tokens, x_tokens), dim=1)
                cls_inserted = True

            x_tokens = block(x_tokens)

        x_tokens = self.backbone.norm(x_tokens)

        if cls_inserted:
            x_tokens = x_tokens[:, 1:, :]

        C = x_tokens.shape[-1]
        feat = x_tokens.transpose(1, 2).reshape(B, C, H_patch, W_patch)

        return feat

    def forward(self, x):
        feat = self.forward_features_as_map(x)
        logits = self.decoder(feat, out_size=x.shape[-2:])
        return logits

# %%
# ============================================================
# Custom experiment runner for CvT / ConViT
# Uses your existing make_loaders, train_one_epoch, validate,
# full_evaluation, plot_history, plot_confusion_matrices.
# ============================================================

def run_custom_experiment(
    model_name,
    model_fn,
    img_size=384,
    augment=False,
    batch_size=8,
    pos_weight=3.0,
    remove_checkpoint_after_eval=True
):
    global IMG_SIZE

    old_img_size = IMG_SIZE
    IMG_SIZE = img_size

    print(f"\n{'='*70}")
    print(f"TRAINING CUSTOM MODEL: {model_name}")
    print(f"Config: {IMG_SIZE}x{IMG_SIZE}, augmentation={augment}, pos_weight={pos_weight}")
    print(f"Batch size: {batch_size}")
    print(f"{'='*70}")

    train_loader, val_loader, test_loader = make_loaders(
        augment=augment,
        batch_size=batch_size,
        include_authentic=True
    )

    model = model_fn().to(DEVICE)

    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    model_size = total_params * 4 / 1024**2

    print(f"Parameters: {total_params:,}")
    print(f"Trainable: {trainable_params:,}")
    print(f"Estimated fp32 model size: {model_size:.1f} MB")

    criterion = DiceBCELoss(pos_weight=pos_weight).to(DEVICE)

    optimizer = torch.optim.AdamW(
        model.parameters(),
        lr=LR,
        weight_decay=WEIGHT_DECAY
    )

    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
        optimizer,
        T_max=NUM_EPOCHS,
        eta_min=1e-6
    )

    scaler = GradScaler(device=DEVICE.type, enabled=USE_AMP)

    history = {
        'train_loss': [],
        'val_loss': [],
        'train_acc': [],
        'val_acc': [],
        'val_f1': [],
        'val_iou': [],
        'val_precision': [],
        'val_recall': [],
        'epoch_time': []
    }

    best_val_iou = -1.0
    best_val_f1 = -1.0
    best_epoch = 0
    total_time = 0.0
    patience_counter = 0

    best_ckpt_path = f'{SAVE_DIR}/best_{model_name}.pth'

    for epoch in range(1, NUM_EPOCHS + 1):
        tl, ta, et = train_one_epoch(model, train_loader, criterion, optimizer, scaler, DEVICE)
        vl, va = validate(model, val_loader, criterion, DEVICE)

        val_eval = full_evaluation(model, val_loader, DEVICE, threshold=BINARY_THRESHOLD)
        val_iou = val_eval['pixel']['iou']
        val_f1 = val_eval['pixel']['f1']

        scheduler.step()
        total_time += et

        history['train_loss'].append(tl)
        history['val_loss'].append(vl)
        history['train_acc'].append(ta)
        history['val_acc'].append(va)
        history['val_f1'].append(val_f1)
        history['val_iou'].append(val_iou)
        history['val_precision'].append(val_eval['pixel']['precision'])
        history['val_recall'].append(val_eval['pixel']['recall'])
        history['epoch_time'].append(et)

        if val_iou > best_val_iou:
            best_val_iou = val_iou
            best_val_f1 = val_f1
            best_epoch = epoch
            patience_counter = 0

            torch.save({
                'model_state_dict': model.state_dict(),
                'epoch': epoch,
                'best_val_iou': best_val_iou,
                'best_val_f1': best_val_f1,
                'model_name': model_name,
                'img_size': IMG_SIZE,
            }, best_ckpt_path)

            improved = "YES"
        else:
            patience_counter += 1
            improved = "NO"

        print(f"Epoch {epoch:>3}/{NUM_EPOCHS} | "
              f"TrLoss: {tl:.4f} TrAcc: {ta:.4f} | "
              f"VlLoss: {vl:.4f} VlAcc: {va:.4f} | "
              f"ValF1: {val_f1:.4f} ValIoU: {val_iou:.4f} | "
              f"{et:.1f}s | Improved: {improved} | Patience: {patience_counter}/{PATIENCE}")

        if patience_counter >= PATIENCE:
            print(f"Early stopping at epoch {epoch}.")
            break

    history['total_time'] = total_time
    history['best_epoch'] = best_epoch
    history['best_val_iou'] = best_val_iou
    history['best_val_f1'] = best_val_f1

    ckpt = torch.load(best_ckpt_path, map_location=DEVICE)
    model.load_state_dict(ckpt['model_state_dict'])

    print(f"\nLoaded best checkpoint from epoch {ckpt['epoch']}")

    results = full_evaluation(model, test_loader, DEVICE, threshold=BINARY_THRESHOLD)

    print(f"\n{'='*60}")
    print(f"TEST SET — {model_name}")
    print(f"{'='*60}")
    print(f"Pixel Accuracy:  {results['pixel']['accuracy']:.4f}")
    print(f"Pixel Precision: {results['pixel']['precision']:.4f}")
    print(f"Pixel Recall:    {results['pixel']['recall']:.4f}")
    print(f"Pixel F1:        {results['pixel']['f1']:.4f}")
    print(f"IoU:             {results['pixel']['iou']:.4f}")
    print(f"Dice:            {results['pixel']['dice']:.4f}")
    print(f"Image F1:        {results['image']['f1']:.4f}")
    print(f"{'='*60}")

    plot_history(history, model_name, SAVE_DIR)
    plot_confusion_matrices(results, model_name, SAVE_DIR)

    ckpt_size_mb = os.path.getsize(best_ckpt_path) / 1024**2 if os.path.exists(best_ckpt_path) else None

    save_data = {
        'model': model_name,
        'encoder_name': model_name,
        'config': {
            'image_size': IMG_SIZE,
            'augmentation': augment,
            'pos_weight': pos_weight,
            'batch_size': batch_size,
            'num_epochs_requested': NUM_EPOCHS,
            'num_epochs_completed': len(history['train_loss']),
            'lr': LR,
            'weight_decay': WEIGHT_DECAY,
            'threshold': BINARY_THRESHOLD,
            'architecture_note': 'Custom transformer feature decoder, not SMP U-Net'
        },
        'test_results': {
            'pixel_metrics': results['pixel'],
            'image_metrics': results['image'],
            'pixel_cm': results['pixel_cm'].tolist(),
            'image_cm': results['image_cm'].tolist(),
        },
        'history': history,
        'model_info': {
            'total_params': total_params,
            'trainable_params': trainable_params,
            'model_size_mb': model_size,
            'checkpoint_size_mb': ckpt_size_mb,
        },
    }

    json_path = f'{SAVE_DIR}/{model_name}_results.json'
    with open(json_path, 'w') as f:
        json.dump(save_data, f, indent=2, default=str)

    print(f"✓ Saved {json_path}")

    if remove_checkpoint_after_eval and os.path.exists(best_ckpt_path):
        os.remove(best_ckpt_path)
        print("✓ Checkpoint removed to save disk")

    del model
    gc.collect()

    if DEVICE.type == 'cuda':
        torch.cuda.empty_cache()

    IMG_SIZE = old_img_size

    return save_data

# %%
# ============================================================
# CvT-13 — 384x384, No Augmentation + pos_weight = 3.0
# ============================================================

cvt13_384_noaug_posw_results = run_custom_experiment(
    model_name='CvT13_384_noaug_posw3',
    model_fn=lambda: HFCvTSeg(
        model_name="microsoft/cvt-13-384",
        img_size=384
    ),
    img_size=384,
    augment=False,
    batch_size=8,
    pos_weight=3.0
)
# Out:
# ======================================================================
# TRAINING CUSTOM MODEL: CvT13_384_noaug_posw3
# Config: 384x384, augmentation=False, pos_weight=3.0
# Batch size: 8
# ======================================================================
# Building datasets | augmentation=False | batch_size=8
#   training: 7559 total (5459 forged, 2100 authentic)
#     fake files found: 5459 | masks found: 4200 | unmatched fakes: 0
#   validation: 1023 total (682 forged, 341 authentic)
#     fake files found: 682 | masks found: 682 | unmatched fakes: 0
#   testing: 1029 total (686 forged, 343 authentic)
#     fake files found: 686 | masks found: 686 | unmatched fakes: 0
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/80.3M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/455 [00:00<?, ?it/s]
# CvtModel LOAD REPORT from: microsoft/cvt-13-384
# Key               | Status     |  |
# ------------------+------------+--+-
# classifier.bias   | UNEXPECTED |  |
# layernorm.bias    | UNEXPECTED |  |
# classifier.weight | UNEXPECTED |  |
# layernorm.weight  | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# model.safetensors:   0%|          | 0.00/80.2M [00:00<?, ?B/s]
# ✓ Built CvT segmentation model: microsoft/cvt-13-384
# Feature shape from dummy input: torch.Size([1, 384, 24, 24])
# Parameters: 20,866,049
# Trainable: 20,866,049
# Estimated fp32 model size: 79.6 MB
# Epoch   1/20 | TrLoss: 0.6410 TrAcc: 0.9136 | VlLoss: 0.5618 VlAcc: 0.9480 | ValF1: 0.4607 ValIoU: 0.2993 | 214.7s | Improved: YES | Patience: 0/5
# Epoch   2/20 | TrLoss: 0.5113 TrAcc: 0.9610 | VlLoss: 0.4949 VlAcc: 0.9527 | ValF1: 0.5084 ValIoU: 0.3408 | 196.9s | Improved: YES | Patience: 0/5
# Epoch   3/20 | TrLoss: 0.4480 TrAcc: 0.9701 | VlLoss: 0.5017 VlAcc: 0.9578 | ValF1: 0.5027 ValIoU: 0.3358 | 196.3s | Improved: NO | Patience: 1/5
# Epoch   4/20 | TrLoss: 0.4103 TrAcc: 0.9743 | VlLoss: 0.4796 VlAcc: 0.9602 | ValF1: 0.5672 ValIoU: 0.3959 | 196.3s | Improved: YES | Patience: 0/5
# Epoch   5/20 | TrLoss: 0.3823 TrAcc: 0.9774 | VlLoss: 0.4763 VlAcc: 0.9560 | ValF1: 0.5552 ValIoU: 0.3843 | 196.3s | Improved: NO | Patience: 1/5
# Epoch   6/20 | TrLoss: 0.3554 TrAcc: 0.9806 | VlLoss: 0.4995 VlAcc: 0.9594 | ValF1: 0.5498 ValIoU: 0.3791 | 196.1s | Improved: NO | Patience: 2/5
# Epoch   7/20 | TrLoss: 0.3296 TrAcc: 0.9825 | VlLoss: 0.4573 VlAcc: 0.9567 | ValF1: 0.5687 ValIoU: 0.3973 | 196.8s | Improved: YES | Patience: 0/5
# Epoch   8/20 | TrLoss: 0.2840 TrAcc: 0.9830 | VlLoss: 0.5565 VlAcc: 0.9665 | ValF1: 0.5738 ValIoU: 0.4023 | 195.9s | Improved: YES | Patience: 0/5
# Epoch   9/20 | TrLoss: 0.2595 TrAcc: 0.9834 | VlLoss: 0.5832 VlAcc: 0.9649 | ValF1: 0.5689 ValIoU: 0.3975 | 195.9s | Improved: NO | Patience: 1/5
# Epoch  10/20 | TrLoss: 0.2415 TrAcc: 0.9849 | VlLoss: 0.6702 VlAcc: 0.9653 | ValF1: 0.5360 ValIoU: 0.3661 | 195.9s | Improved: NO | Patience: 2/5
# Epoch  11/20 | TrLoss: 0.2225 TrAcc: 0.9861 | VlLoss: 0.6165 VlAcc: 0.9655 | ValF1: 0.5615 ValIoU: 0.3904 | 195.6s | Improved: NO | Patience: 3/5
# Epoch  12/20 | TrLoss: 0.2143 TrAcc: 0.9864 | VlLoss: 0.6031 VlAcc: 0.9662 | ValF1: 0.5729 ValIoU: 0.4014 | 195.7s | Improved: NO | Patience: 4/5
# Epoch  13/20 | TrLoss: 0.1964 TrAcc: 0.9875 | VlLoss: 0.5949 VlAcc: 0.9661 | ValF1: 0.5721 ValIoU: 0.4006 | 195.2s | Improved: NO | Patience: 5/5
# Early stopping at epoch 13.
#
# Loaded best checkpoint from epoch 8
#
# ============================================================
# TEST SET — CvT13_384_noaug_posw3
# ============================================================
# Pixel Accuracy:  0.9650
# Pixel Precision: 0.5985
# Pixel Recall:    0.5207
# Pixel F1:        0.5569
# IoU:             0.3859
# Dice:            0.5569
# Image F1:        0.7498
# ============================================================
# ✓ Saved /kaggle/working/CvT13_384_noaug_posw3_results.json
# ✓ Checkpoint removed to save disk

# %%
# ============================================================
# CvT-13 — 384x384, WITH Augmentation + pos_weight = 3.0
# ============================================================

cvt13_384_aug_posw_results = run_custom_experiment(
    model_name='CvT13_384_aug_posw3',
    model_fn=lambda: HFCvTSeg(
        model_name="microsoft/cvt-13-384",
        img_size=384
    ),
    img_size=384,
    augment=True,
    batch_size=8,
    pos_weight=3.0
)
# Out:
# ======================================================================
# TRAINING CUSTOM MODEL: CvT13_384_aug_posw3
# Config: 384x384, augmentation=True, pos_weight=3.0
# Batch size: 8
# ======================================================================
# Building datasets | augmentation=True | batch_size=8
#   training: 7559 total (5459 forged, 2100 authentic)
#     fake files found: 5459 | masks found: 4200 | unmatched fakes: 0
#   validation: 1023 total (682 forged, 341 authentic)
#     fake files found: 682 | masks found: 682 | unmatched fakes: 0
#   testing: 1029 total (686 forged, 343 authentic)
#     fake files found: 686 | masks found: 686 | unmatched fakes: 0
# Loading weights:   0%|          | 0/455 [00:00<?, ?it/s]
# CvtModel LOAD REPORT from: microsoft/cvt-13-384
# Key               | Status     |  |
# ------------------+------------+--+-
# classifier.bias   | UNEXPECTED |  |
# layernorm.bias    | UNEXPECTED |  |
# classifier.weight | UNEXPECTED |  |
# layernorm.weight  | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✓ Built CvT segmentation model: microsoft/cvt-13-384
# Feature shape from dummy input: torch.Size([1, 384, 24, 24])
# Parameters: 20,866,049
# Trainable: 20,866,049
# Estimated fp32 model size: 79.6 MB
# Epoch   1/20 | TrLoss: 0.6397 TrAcc: 0.9151 | VlLoss: 0.5303 VlAcc: 0.9493 | ValF1: 0.4672 ValIoU: 0.3048 | 200.7s | Improved: YES | Patience: 0/5
# Epoch   2/20 | TrLoss: 0.5379 TrAcc: 0.9541 | VlLoss: 0.4943 VlAcc: 0.9532 | ValF1: 0.5028 ValIoU: 0.3358 | 200.7s | Improved: YES | Patience: 0/5
# Epoch   3/20 | TrLoss: 0.4959 TrAcc: 0.9614 | VlLoss: 0.4767 VlAcc: 0.9559 | ValF1: 0.5430 ValIoU: 0.3727 | 200.7s | Improved: YES | Patience: 0/5
# Epoch   4/20 | TrLoss: 0.4644 TrAcc: 0.9662 | VlLoss: 0.5031 VlAcc: 0.9594 | ValF1: 0.5176 ValIoU: 0.3492 | 199.3s | Improved: NO | Patience: 1/5
# Epoch   5/20 | TrLoss: 0.4445 TrAcc: 0.9687 | VlLoss: 0.4753 VlAcc: 0.9555 | ValF1: 0.5403 ValIoU: 0.3701 | 199.3s | Improved: NO | Patience: 2/5
# Epoch   6/20 | TrLoss: 0.4227 TrAcc: 0.9723 | VlLoss: 0.4676 VlAcc: 0.9610 | ValF1: 0.5828 ValIoU: 0.4112 | 199.4s | Improved: YES | Patience: 0/5
# Epoch   7/20 | TrLoss: 0.4086 TrAcc: 0.9736 | VlLoss: 0.4830 VlAcc: 0.9625 | ValF1: 0.5683 ValIoU: 0.3969 | 199.3s | Improved: NO | Patience: 1/5
# Epoch   8/20 | TrLoss: 0.3918 TrAcc: 0.9760 | VlLoss: 0.4912 VlAcc: 0.9648 | ValF1: 0.5732 ValIoU: 0.4017 | 198.2s | Improved: NO | Patience: 2/5
# Epoch   9/20 | TrLoss: 0.3799 TrAcc: 0.9775 | VlLoss: 0.4708 VlAcc: 0.9582 | ValF1: 0.5717 ValIoU: 0.4003 | 199.8s | Improved: NO | Patience: 3/5
# Epoch  10/20 | TrLoss: 0.3745 TrAcc: 0.9781 | VlLoss: 0.5330 VlAcc: 0.9664 | ValF1: 0.5570 ValIoU: 0.3860 | 200.1s | Improved: NO | Patience: 4/5
# Epoch  11/20 | TrLoss: 0.3599 TrAcc: 0.9801 | VlLoss: 0.4907 VlAcc: 0.9659 | ValF1: 0.6118 ValIoU: 0.4407 | 199.4s | Improved: YES | Patience: 0/5
# Epoch  12/20 | TrLoss: 0.3593 TrAcc: 0.9800 | VlLoss: 0.5001 VlAcc: 0.9663 | ValF1: 0.6023 ValIoU: 0.4309 | 198.6s | Improved: NO | Patience: 1/5
# Epoch  13/20 | TrLoss: 0.3488 TrAcc: 0.9815 | VlLoss: 0.5028 VlAcc: 0.9681 | ValF1: 0.6130 ValIoU: 0.4420 | 199.3s | Improved: YES | Patience: 0/5
# Epoch  14/20 | TrLoss: 0.3373 TrAcc: 0.9828 | VlLoss: 0.5091 VlAcc: 0.9674 | ValF1: 0.6005 ValIoU: 0.4291 | 199.9s | Improved: NO | Patience: 1/5
# Epoch  15/20 | TrLoss: 0.3057 TrAcc: 0.9824 | VlLoss: 0.5102 VlAcc: 0.9691 | ValF1: 0.6212 ValIoU: 0.4505 | 199.5s | Improved: YES | Patience: 0/5
# Epoch  16/20 | TrLoss: 0.2847 TrAcc: 0.9832 | VlLoss: 0.5565 VlAcc: 0.9696 | ValF1: 0.6040 ValIoU: 0.4326 | 199.0s | Improved: NO | Patience: 1/5
# Epoch  17/20 | TrLoss: 0.2744 TrAcc: 0.9834 | VlLoss: 0.5226 VlAcc: 0.9704 | ValF1: 0.6195 ValIoU: 0.4487 | 200.3s | Improved: NO | Patience: 2/5
# Epoch  18/20 | TrLoss: 0.2688 TrAcc: 0.9843 | VlLoss: 0.5179 VlAcc: 0.9704 | ValF1: 0.6252 ValIoU: 0.4548 | 199.9s | Improved: YES | Patience: 0/5
# Epoch  19/20 | TrLoss: 0.2677 TrAcc: 0.9844 | VlLoss: 0.5463 VlAcc: 0.9701 | ValF1: 0.6126 ValIoU: 0.4416 | 199.7s | Improved: NO | Patience: 1/5
# Epoch  20/20 | TrLoss: 0.2582 TrAcc: 0.9848 | VlLoss: 0.5382 VlAcc: 0.9703 | ValF1: 0.6233 ValIoU: 0.4527 | 199.8s | Improved: NO | Patience: 2/5
#
# Loaded best checkpoint from epoch 18
#
# ============================================================
# TEST SET — CvT13_384_aug_posw3
# ============================================================
# Pixel Accuracy:  0.9708
# Pixel Precision: 0.6997
# Pixel Recall:    0.5424
# Pixel F1:        0.6111
# IoU:             0.4400
# Dice:            0.6111
# Image F1:        0.7411
# ============================================================
# ✓ Saved /kaggle/working/CvT13_384_aug_posw3_results.json
# ✓ Checkpoint removed to save disk

# %%
# ============================================================
# MaxViT-Tiny — 384x384, No Augmentation + pos_weight = 3.0
# ============================================================

IMG_SIZE = 384

maxvit_tiny_384_noaug_posw_results = run_experiment(
    model_name='MaxViTTiny_384_noaug_posw3',
    encoder_name='tu-maxvit_tiny_tf_384',
    augment=False,
    batch_size=8,
    pos_weight=3.0,
    encoder_depth=5
)

experiment_summaries.append(maxvit_tiny_384_noaug_posw_results)
# Out:
# ======================================================================
# TRAINING: MaxViTTiny_384_noaug_posw3
# Encoder: tu-maxvit_tiny_tf_384
# Config: 384x384, augmentation=False, pos_weight=3.0
# Batch size: 8
# ======================================================================
# Building datasets | augmentation=False | batch_size=8
#   training: 7559 total (5459 forged, 2100 authentic)
#     fake files found: 5459 | masks found: 4200 | unmatched fakes: 0
#   validation: 1023 total (682 forged, 341 authentic)
#     fake files found: 682 | masks found: 682 | unmatched fakes: 0
#   testing: 1029 total (686 forged, 343 authentic)
#     fake files found: 686 | masks found: 686 | unmatched fakes: 0
# Parameters: 33,352,025
# Trainable: 33,352,025
# Estimated fp32 model size: 127.2 MB
# Epoch   1/20 | TrLoss: 0.5219 TrAcc: 0.9421 | VlLoss: 0.4632 VlAcc: 0.9603 | ValF1: 0.5850 ValIoU: 0.4135 | 405.2s | Improved: YES | Patience: 0/5
# Epoch   2/20 | TrLoss: 0.3722 TrAcc: 0.9739 | VlLoss: 0.3940 VlAcc: 0.9739 | ValF1: 0.7187 ValIoU: 0.5609 | 354.6s | Improved: YES | Patience: 0/5
# Epoch   3/20 | TrLoss: 0.3008 TrAcc: 0.9836 | VlLoss: 0.3762 VlAcc: 0.9805 | ValF1: 0.7748 ValIoU: 0.6323 | 353.3s | Improved: YES | Patience: 0/5
# Epoch   4/20 | TrLoss: 0.2616 TrAcc: 0.9884 | VlLoss: 0.3448 VlAcc: 0.9822 | ValF1: 0.8067 ValIoU: 0.6760 | 353.2s | Improved: YES | Patience: 0/5
# Epoch   5/20 | TrLoss: 0.2229 TrAcc: 0.9910 | VlLoss: 0.2784 VlAcc: 0.9830 | ValF1: 0.8173 ValIoU: 0.6910 | 352.7s | Improved: YES | Patience: 0/5
# Epoch   6/20 | TrLoss: 0.1431 TrAcc: 0.9921 | VlLoss: 0.2710 VlAcc: 0.9851 | ValF1: 0.8358 ValIoU: 0.7179 | 351.5s | Improved: YES | Patience: 0/5
# Epoch   7/20 | TrLoss: 0.1111 TrAcc: 0.9934 | VlLoss: 0.3081 VlAcc: 0.9857 | ValF1: 0.8253 ValIoU: 0.7026 | 350.4s | Improved: NO | Patience: 1/5
# Epoch   8/20 | TrLoss: 0.0943 TrAcc: 0.9945 | VlLoss: 0.2557 VlAcc: 0.9871 | ValF1: 0.8534 ValIoU: 0.7443 | 351.3s | Improved: YES | Patience: 0/5
# Epoch   9/20 | TrLoss: 0.0790 TrAcc: 0.9954 | VlLoss: 0.2823 VlAcc: 0.9878 | ValF1: 0.8578 ValIoU: 0.7510 | 351.7s | Improved: YES | Patience: 0/5
# Epoch  10/20 | TrLoss: 0.0657 TrAcc: 0.9960 | VlLoss: 0.2660 VlAcc: 0.9880 | ValF1: 0.8598 ValIoU: 0.7540 | 351.3s | Improved: YES | Patience: 0/5
# Epoch  11/20 | TrLoss: 0.0562 TrAcc: 0.9965 | VlLoss: 0.2435 VlAcc: 0.9885 | ValF1: 0.8694 ValIoU: 0.7690 | 351.6s | Improved: YES | Patience: 0/5
# Epoch  12/20 | TrLoss: 0.0494 TrAcc: 0.9969 | VlLoss: 0.2614 VlAcc: 0.9885 | ValF1: 0.8668 ValIoU: 0.7649 | 350.7s | Improved: NO | Patience: 1/5
# Epoch  13/20 | TrLoss: 0.0422 TrAcc: 0.9972 | VlLoss: 0.2495 VlAcc: 0.9889 | ValF1: 0.8717 ValIoU: 0.7725 | 351.1s | Improved: YES | Patience: 0/5
# Epoch  14/20 | TrLoss: 0.0371 TrAcc: 0.9975 | VlLoss: 0.2437 VlAcc: 0.9890 | ValF1: 0.8736 ValIoU: 0.7756 | 351.3s | Improved: YES | Patience: 0/5
# Epoch  15/20 | TrLoss: 0.0332 TrAcc: 0.9978 | VlLoss: 0.2263 VlAcc: 0.9895 | ValF1: 0.8815 ValIoU: 0.7881 | 351.5s | Improved: YES | Patience: 0/5
# Epoch  16/20 | TrLoss: 0.0293 TrAcc: 0.9980 | VlLoss: 0.2558 VlAcc: 0.9890 | ValF1: 0.8730 ValIoU: 0.7747 | 351.9s | Improved: NO | Patience: 1/5
# Epoch  17/20 | TrLoss: 0.0265 TrAcc: 0.9981 | VlLoss: 0.2551 VlAcc: 0.9889 | ValF1: 0.8710 ValIoU: 0.7715 | 351.5s | Improved: NO | Patience: 2/5
# Epoch  18/20 | TrLoss: 0.0252 TrAcc: 0.9982 | VlLoss: 0.2538 VlAcc: 0.9889 | ValF1: 0.8716 ValIoU: 0.7725 | 350.9s | Improved: NO | Patience: 3/5
# Epoch  19/20 | TrLoss: 0.0236 TrAcc: 0.9983 | VlLoss: 0.2625 VlAcc: 0.9887 | ValF1: 0.8684 ValIoU: 0.7675 | 351.1s | Improved: NO | Patience: 4/5
# Epoch  20/20 | TrLoss: 0.0239 TrAcc: 0.9983 | VlLoss: 0.2624 VlAcc: 0.9888 | ValF1: 0.8692 ValIoU: 0.7686 | 352.4s | Improved: NO | Patience: 5/5
# Early stopping at epoch 20.
#
# Training complete.
# Best epoch: 15
# Best val IoU: 0.7881
# Best val F1: 0.8815
# Total time: 7090s
# Loaded best checkpoint from epoch 15 (val IoU: 0.7881)
#
# ============================================================
# TEST SET — MaxViTTiny_384_noaug_posw3
# ============================================================
# Pixel Accuracy:  0.9894
# Pixel Precision: 0.8877
# Pixel Recall:    0.8562
# Pixel F1:        0.8717
# IoU:             0.7725
# Dice:            0.8717
# Image Accuracy:  0.8095
# Image Precision: 0.8914
# Image Recall:    0.8134
# Image F1:        0.8506
# ============================================================
# Parameters: 33,352,025
# Model size: 127.2 MB
# Total training time: 7090s
# Avg epoch time: 354.5s
# ✓ Saved /kaggle/working/MaxViTTiny_384_noaug_posw3_results.json
#
# ============================================================
# COPY-PASTE BACKUP:
# {
#   "model": "MaxViTTiny_384_noaug_posw3",
#   "pixel": {
#     "accuracy": 0.9893524331390542,
#     "precision": 0.8877024298049151,
#     "recall": 0.8561706957092116,
#     "f1": 0.8716514882084723,
#     "iou": 0.7725020133044952,
#     "dice": 0.8716514932068383
#   },
#   "image": {
#     "accuracy": 0.8095238095238095,
#     "precision": 0.8913738019169329,
#     "recall": 0.8134110787172012,
#     "f1": 0.850609756097561
#   },
#   "params": 33352025,
#   "size_mb": 127.22787857055664,
#   "best_epoch": 15,
#   "total_time": 7089.523872852325
# }
# ============================================================
# ✓ Checkpoint removed to save disk
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_57/3469124983.py in <cell line: 0>()
#      14 )
#      15
# ---> 16 experiment_summaries.append(maxvit_tiny_384_noaug_posw_results)
#
# NameError: name 'experiment_summaries' is not defined

# %%
# ============================================================
# MaxViT-Tiny — 384x384, WITH Augmentation + pos_weight = 3.0
# ============================================================

IMG_SIZE = 384

maxvit_tiny_384_aug_posw_results = run_experiment(
    model_name='MaxViTTiny_384_aug_posw3',
    encoder_name='tu-maxvit_tiny_tf_384',
    augment=True,
    batch_size=8,
    pos_weight=3.0,
    encoder_depth=5
)

experiment_summaries.append(maxvit_tiny_384_aug_posw_results)
# Out:
# ======================================================================
# TRAINING: MaxViTTiny_384_aug_posw3
# Encoder: tu-maxvit_tiny_tf_384
# Config: 384x384, augmentation=True, pos_weight=3.0
# Batch size: 8
# ======================================================================
# Building datasets | augmentation=True | batch_size=8
#   training: 7559 total (5459 forged, 2100 authentic)
#     fake files found: 5459 | masks found: 4200 | unmatched fakes: 0
#   validation: 1023 total (682 forged, 341 authentic)
#     fake files found: 682 | masks found: 682 | unmatched fakes: 0
#   testing: 1029 total (686 forged, 343 authentic)
#     fake files found: 686 | masks found: 686 | unmatched fakes: 0
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors:   0%|          | 0.00/124M [00:00<?, ?B/s]
# Parameters: 33,352,025
# Trainable: 33,352,025
# Estimated fp32 model size: 127.2 MB
# Epoch   1/20 | TrLoss: 0.6174 TrAcc: 0.8874 | VlLoss: 0.4709 VlAcc: 0.9628 | ValF1: 0.6171 ValIoU: 0.4462 | 421.0s | Improved: YES | Patience: 0/5
# Epoch   2/20 | TrLoss: 0.4170 TrAcc: 0.9709 | VlLoss: 0.3928 VlAcc: 0.9713 | ValF1: 0.7099 ValIoU: 0.5503 | 370.5s | Improved: YES | Patience: 0/5
# Epoch   3/20 | TrLoss: 0.3479 TrAcc: 0.9794 | VlLoss: 0.3640 VlAcc: 0.9798 | ValF1: 0.7749 ValIoU: 0.6325 | 369.6s | Improved: YES | Patience: 0/5
# Epoch   4/20 | TrLoss: 0.3069 TrAcc: 0.9840 | VlLoss: 0.3291 VlAcc: 0.9803 | ValF1: 0.7952 ValIoU: 0.6600 | 369.9s | Improved: YES | Patience: 0/5
# Epoch   5/20 | TrLoss: 0.2806 TrAcc: 0.9869 | VlLoss: 0.3293 VlAcc: 0.9833 | ValF1: 0.8137 ValIoU: 0.6860 | 369.3s | Improved: YES | Patience: 0/5
# Epoch   6/20 | TrLoss: 0.2611 TrAcc: 0.9888 | VlLoss: 0.3062 VlAcc: 0.9831 | ValF1: 0.8282 ValIoU: 0.7068 | 368.0s | Improved: YES | Patience: 0/5
# Epoch   7/20 | TrLoss: 0.2458 TrAcc: 0.9906 | VlLoss: 0.3137 VlAcc: 0.9889 | ValF1: 0.8770 ValIoU: 0.7810 | 367.8s | Improved: YES | Patience: 0/5
# Epoch   8/20 | TrLoss: 0.1828 TrAcc: 0.9915 | VlLoss: 0.2345 VlAcc: 0.9886 | ValF1: 0.8680 ValIoU: 0.7668 | 367.9s | Improved: NO | Patience: 1/5
# Epoch   9/20 | TrLoss: 0.1474 TrAcc: 0.9924 | VlLoss: 0.2090 VlAcc: 0.9889 | ValF1: 0.8766 ValIoU: 0.7803 | 365.3s | Improved: NO | Patience: 2/5
# Epoch  10/20 | TrLoss: 0.1264 TrAcc: 0.9933 | VlLoss: 0.1842 VlAcc: 0.9890 | ValF1: 0.8828 ValIoU: 0.7901 | 364.6s | Improved: YES | Patience: 0/5
# Epoch  11/20 | TrLoss: 0.1143 TrAcc: 0.9938 | VlLoss: 0.1895 VlAcc: 0.9895 | ValF1: 0.8846 ValIoU: 0.7930 | 364.2s | Improved: YES | Patience: 0/5
# Epoch  12/20 | TrLoss: 0.1011 TrAcc: 0.9945 | VlLoss: 0.1813 VlAcc: 0.9910 | ValF1: 0.8993 ValIoU: 0.8170 | 365.6s | Improved: YES | Patience: 0/5
# Epoch  13/20 | TrLoss: 0.0917 TrAcc: 0.9948 | VlLoss: 0.1898 VlAcc: 0.9909 | ValF1: 0.8977 ValIoU: 0.8143 | 363.7s | Improved: NO | Patience: 1/5
# Epoch  14/20 | TrLoss: 0.0862 TrAcc: 0.9951 | VlLoss: 0.1645 VlAcc: 0.9908 | ValF1: 0.9003 ValIoU: 0.8186 | 363.7s | Improved: YES | Patience: 0/5
# Epoch  15/20 | TrLoss: 0.0780 TrAcc: 0.9954 | VlLoss: 0.1674 VlAcc: 0.9915 | ValF1: 0.9056 ValIoU: 0.8274 | 363.6s | Improved: YES | Patience: 0/5
# Epoch  16/20 | TrLoss: 0.0740 TrAcc: 0.9957 | VlLoss: 0.1669 VlAcc: 0.9917 | ValF1: 0.9071 ValIoU: 0.8300 | 364.4s | Improved: YES | Patience: 0/5
# Epoch  17/20 | TrLoss: 0.0695 TrAcc: 0.9959 | VlLoss: 0.1583 VlAcc: 0.9920 | ValF1: 0.9113 ValIoU: 0.8370 | 363.5s | Improved: YES | Patience: 0/5
# Epoch  18/20 | TrLoss: 0.0686 TrAcc: 0.9959 | VlLoss: 0.1605 VlAcc: 0.9921 | ValF1: 0.9116 ValIoU: 0.8375 | 364.6s | Improved: YES | Patience: 0/5
# Epoch  19/20 | TrLoss: 0.0657 TrAcc: 0.9960 | VlLoss: 0.1646 VlAcc: 0.9918 | ValF1: 0.9090 ValIoU: 0.8332 | 364.5s | Improved: NO | Patience: 1/5
# Epoch  20/20 | TrLoss: 0.0647 TrAcc: 0.9961 | VlLoss: 0.1659 VlAcc: 0.9918 | ValF1: 0.9088 ValIoU: 0.8329 | 363.9s | Improved: NO | Patience: 2/5
#
# Training complete.
# Best epoch: 18
# Best val IoU: 0.8375
# Best val F1: 0.9116
# Total time: 7375s
# Loaded best checkpoint from epoch 18 (val IoU: 0.8375)
#
# ============================================================
# TEST SET — MaxViTTiny_384_aug_posw3
# ============================================================
# Pixel Accuracy:  0.9916
# Pixel Precision: 0.9272
# Pixel Recall:    0.8699
# Pixel F1:        0.8976
# IoU:             0.8143
# Dice:            0.8976
# Image Accuracy:  0.8426
# Image Precision: 0.9107
# Image Recall:    0.8469
# Image F1:        0.8776
# ============================================================
# Parameters: 33,352,025
# Model size: 127.2 MB
# Total training time: 7375s
# Avg epoch time: 368.8s
# ✓ Saved /kaggle/working/MaxViTTiny_384_aug_posw3_results.json
#
# ============================================================
# COPY-PASTE BACKUP:
# {
#   "model": "MaxViTTiny_384_aug_posw3",
#   "pixel": {
#     "accuracy": 0.9916211931356124,
#     "precision": 0.9272212713968954,
#     "recall": 0.8698636711026516,
#     "f1": 0.8976271243492868,
#     "iou": 0.8142681602915283,
#     "dice": 0.8976271293441941
#   },
#   "image": {
#     "accuracy": 0.8425655976676385,
#     "precision": 0.9106583072100314,
#     "recall": 0.8469387755102041,
#     "f1": 0.877643504531722
#   },
#   "params": 33352025,
#   "size_mb": 127.22787857055664,
#   "best_epoch": 18,
#   "total_time": 7375.499819993973
# }
# ============================================================
# ✓ Checkpoint removed to save disk
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_57/3033400532.py in <cell line: 0>()
#      14 )
#      15
# ---> 16 experiment_summaries.append(maxvit_tiny_384_aug_posw_results)
#
# NameError: name 'experiment_summaries' is not defined
